# %%
# =============================================================================
# Annual Ozone, Temperature, Mortality, Population data in Japan 
# Python translation of your R script
# =============================================================================

import pandas as pd
import numpy as np
import glob
import os
import re
from pathlib import Path

#Dependent Variables: Annual Deaths from Heat-Related Causes
#Independent Variables: Ozone, Temperature, Mortality, Population

# %%
# Set base directory
BASE_DIR = Path(r"/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2")

# Example: join subfolders and files
ozone_file_path = BASE_DIR / "Air_Pollutant" / "Oxidant_txt" / "TD19760613.txt"

print(ozone_file_path)
# Out:
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19760613.txt

# %%
# =============================================================================
# OZONE DATA
# =============================================================================

# Japanese → English column mapping
jp_to_en = {
    "測定年度": "year_recorded",
    "都道府県名": "prefecture",
    "市区町村コード": "city_code",
    "市区町村名": "city_name",
    "測定局名": "station_name",
    "用途地域名": "use_zone",
    "昼間の１時間値が0.06ppmを超えた日数(日)": "days_over_0_06",
    "昼間の１時間値が0.06ppmを超えた時間数(時間)": "hours_over_0_06",
    "昼間の１時間値の最高値(ppm)": "max_hourly_ppm",
    "昼間の日最高１時間値の年平均値(ppm)": "mean_annual_daytime_peak_ppm",
}

def year_from_filename(path):
    """Extract year from filename like TD19760613.txt (R: substr 3,6)."""
    fname = os.path.basename(path)
    return int(fname[2:6])

def read_tokyo_file(path):
    """Read ozone CSV with shift-jis/CP932 encoding."""
    return pd.read_csv(path, encoding="cp932")

def summarise_wards(path):
    raw = read_tokyo_file(path)
    keep_cols = [c for c in raw.columns if c in jp_to_en]
    df = raw[keep_cols].copy()

    # Rename to English
    df = df.rename(columns=jp_to_en)

    # city_code as string
    if "city_code" in df.columns:
        df["city_code"] = df["city_code"].astype(str)

        # keep city codes where 3rd char == "1"
        df = df[df["city_code"].str[2:3] == "1"]

    # filter use_zone == "住"
    if "use_zone" in df.columns and ("住" in df["use_zone"].dropna().values):
        df = df[df["use_zone"] == "住"]

    # If empty → return NA values
    if df.shape[0] == 0:
        yr = year_from_filename(path)
        return pd.DataFrame({
            "year": [yr],
            "mean_days_over_0_06": [np.nan],
            "mean_hours_over_0_06": [np.nan],
            "mean_max_hourly_ppm": [np.nan],
            "mean_annual_daytime_peak_ppm": [np.nan]
        })

    yr = year_from_filename(path)
    # Ensure numeric conversion for all relevant columns
    df["days_over_0_06"] = pd.to_numeric(df["days_over_0_06"], errors="coerce")
    df["hours_over_0_06"] = pd.to_numeric(df["hours_over_0_06"], errors="coerce")
    df["max_hourly_ppm"] = pd.to_numeric(df["max_hourly_ppm"], errors="coerce")
    df["mean_annual_daytime_peak_ppm"] = pd.to_numeric(df["mean_annual_daytime_peak_ppm"], errors="coerce")
    
    out = pd.DataFrame({
        "year": [yr],
        "mean_days_over_0_06": [df["days_over_0_06"].mean()],
        "mean_hours_over_0_06": [df["hours_over_0_06"].mean()],
        "mean_max_hourly_ppm": [df["max_hourly_ppm"].mean()],
        "mean_annual_daytime_peak_ppm": [df["mean_annual_daytime_peak_ppm"].mean()]
    })
    return out

# %%
# ---- apply to all files ----
ozone_dir = BASE_DIR / "Air_Pollutant" / "Oxidant_txt"
print("Looking in:", ozone_dir)
print("Exists?", ozone_dir.exists())
print("Contents:", list(ozone_dir.iterdir()) if ozone_dir.exists() else "Folder not found")

# glob needs a string pattern
ozone_files = sorted(glob.glob(str(ozone_dir / "TD*.txt")))
print("Ozone files found:", ozone_files)

if ozone_files:
    ozone_list = [summarise_wards(f) for f in ozone_files]
    df_results_ozone = pd.concat(ozone_list).sort_values("year").reset_index(drop=True)
else:
    print("No ozone files found to process.")
    df_results_ozone = pd.DataFrame(columns=[
        "year", "mean_days_over_0_06", "mean_hours_over_0_06",
        "mean_max_hourly_ppm", "mean_annual_daytime_peak_ppm"
    ])
# Out:
# Looking in: /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt
# Exists? True
# Contents: [PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20220613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19980613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19880613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19750613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19810613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19910613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20140613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20040613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19740613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/.DS_Store'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19900613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19800613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20050613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20150613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19890613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19990613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19760613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20170613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20070613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19820613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19920613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20210613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20200613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19770613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20060613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20160613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19930613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19830613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19860613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19960613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20130613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20030613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19720613.txt'), PosixPath('/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19970613.txt'), PosixPath('/Users/apple/Desktop/2025_research_pape ...
# Ozone files found: ['/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19710613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19720613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19730613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19740613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19750613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19760613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19770613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19780613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19790613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19800613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19810613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19820613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19830613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19840613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19850613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19860613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19870613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19880613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19890613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19900613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19910613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19920613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19930613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19940613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19950613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19960613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19970613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19980613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD19990613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20000613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20010613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20020613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20030613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20040613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20050613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20060613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20070613.txt', '/Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Air_Pollutant/Oxidant_txt/TD20080 ...

# %%
print(df_results_ozone.head(52))
# Out:
#     year  mean_days_over_0_06  mean_hours_over_0_06  mean_max_hourly_ppm  \
# 0   1971                  NaN                   NaN             0.227778
# 1   1972                  NaN                   NaN             0.251818
# 2   1973                  NaN           1293.500000             0.254167
# 3   1974            88.222222            333.222222             0.195556
# 4   1975           127.333333            539.095238             0.239048
# 5   1976           124.523810            477.333333             0.226667
# 6   1977            54.238095            145.476190             0.151905
# 7   1978            24.952381             72.285714             0.119048
# 8   1979            17.333333             55.333333             0.120952
# 9   1980            12.190476             32.619048             0.100000
# 10  1981            11.619048             33.666667             0.096667
# 11  1982            17.666667             59.142857             0.122857
# 12  1983            34.809524            119.904762             0.116381
# 13  1984            31.476190            106.476190             0.144905
# 14  1985            34.666667            117.857143             0.120524
# 15  1986            20.047619             57.619048             0.096048
# 16  1987            38.937500            155.812500             0.147437
# 17  1988            26.625000             83.625000             0.118375
# 18  1989            21.125000             63.375000             0.105875
# 19  1990            44.411765            155.000000             0.144412
# 20  1991            51.111111            214.222222             0.177389
# 21  1992            46.368421            187.947368             0.137632
# 22  1993            31.210526            110.157895             0.146368
# 23  1994            56.263158            228.000000             0.170263
# 24  1995            51.631579            192.631579             0.144421
# 25  1996            41.421053            147.894737             0.125421
# 26  1997            51.368421            198.789474             0.129947
# 27  1998            47.500000            187.833333             0.158556
# 28  1999            61.166667            260.000000             0.127889
# 29  2000            74.388889            330.166667             0.151500
# 30  2001            78.000000            358.944444             0.168667
# 31  2002            71.777778            351.277778             0.188222
# 32  2003            61.055556            259.611111             0.170556
# 33  2004            71.888889            344.222222             0.180500
# 34  2005            78.111111            357.611111             0.156500
# 35  2006            73.222222            319.555556             0.164167
# 36  2007            75.222222            374.777778             0.151889
# 37  2008            81.111111            379.000000             0.145333
# 38  2009            75.777778            360.277778             0.127333
# 39  2010            81.176471            408.941176             0.186353
# 40  2011            55.333333            243.222222             0.122278
# 41  2012            57.333333            245.888889             0.142833
# 42  2013            80.222222            371.833333             0.169500
# 43  2014            82.611111            379.833333             0.140944
# 44  2015            76.888889            345.777778             0.156944
# 45  2016            63.055556            259.888889             0.127333
# 46  2017            79.388889            351.722222             0.148278
# 47  2018            70.722222            368.611111             0.140889
# 48  2019            64.944444            306.111111             0.166222
# 49  2020            64.833333            270.666667             0.161111
# 50  2021            62.833333            262.722222             0.140111
# 51  2022            59.000000            270.777778             0.159389
#
#     mean_annual_daytime_peak_ppm
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                       0.060286
# 6                       0.048476
# 7                       0.029952
# 8                       0.029095
# 9                       0.027905
# 10                      0.026762
# 11                      0.029524
# 12                      0.033762
# 13                      0.035429
# 14                      0.033667
# 15                      0.028476
# 16                      0.033563
# 17                      0.030062
# 18                      0.028438
# 19                      0.037529
# 20                      0.037111
# 21                      0.038789
# 22                      0.034789
# 23                      0.040000
# 24                      0.040737
# 25                      0.037789
# 26                      0.039105
# 27                      0.037000
# 28                      0.040056
# 29                      0.042000
# 30                      0.044722
# 31                      0.043389
# 32                      0.041611
# 33                      0.043611
# 34                      0.045667
# 35                      0.044278
# 36                      0.044389
# 37                      0.046111
# 38                      0.044556
# 39                      0.047471
# 40                      0.041000
# 41                      0.043333
# 42                      0.046389
# 43                      0.045722
# 44                      0.046000
# 45                      0.044222
# 46                      0.046722
# 47                      0.046111
# 48                      0.045611
# 49                      0.044944
# 50                      0.046444
# 51                      0.045500

# %%
# ---- lag 1 year ----
df_results_ozone_lagged = df_results_ozone.copy()
for col in [
    "mean_days_over_0_06",
    "mean_hours_over_0_06",
    "mean_max_hourly_ppm",
    "mean_annual_daytime_peak_ppm"
]:
    df_results_ozone_lagged[col + "_lag1"] = df_results_ozone_lagged[col].shift(1)

# -----------------------------
# Preview results
# -----------------------------
print(df_results_ozone_lagged.head(52))
# Out:
#     year  mean_days_over_0_06  mean_hours_over_0_06  mean_max_hourly_ppm  \
# 0   1971                  NaN                   NaN             0.227778
# 1   1972                  NaN                   NaN             0.251818
# 2   1973                  NaN           1293.500000             0.254167
# 3   1974            88.222222            333.222222             0.195556
# 4   1975           127.333333            539.095238             0.239048
# 5   1976           124.523810            477.333333             0.226667
# 6   1977            54.238095            145.476190             0.151905
# 7   1978            24.952381             72.285714             0.119048
# 8   1979            17.333333             55.333333             0.120952
# 9   1980            12.190476             32.619048             0.100000
# 10  1981            11.619048             33.666667             0.096667
# 11  1982            17.666667             59.142857             0.122857
# 12  1983            34.809524            119.904762             0.116381
# 13  1984            31.476190            106.476190             0.144905
# 14  1985            34.666667            117.857143             0.120524
# 15  1986            20.047619             57.619048             0.096048
# 16  1987            38.937500            155.812500             0.147437
# 17  1988            26.625000             83.625000             0.118375
# 18  1989            21.125000             63.375000             0.105875
# 19  1990            44.411765            155.000000             0.144412
# 20  1991            51.111111            214.222222             0.177389
# 21  1992            46.368421            187.947368             0.137632
# 22  1993            31.210526            110.157895             0.146368
# 23  1994            56.263158            228.000000             0.170263
# 24  1995            51.631579            192.631579             0.144421
# 25  1996            41.421053            147.894737             0.125421
# 26  1997            51.368421            198.789474             0.129947
# 27  1998            47.500000            187.833333             0.158556
# 28  1999            61.166667            260.000000             0.127889
# 29  2000            74.388889            330.166667             0.151500
# 30  2001            78.000000            358.944444             0.168667
# 31  2002            71.777778            351.277778             0.188222
# 32  2003            61.055556            259.611111             0.170556
# 33  2004            71.888889            344.222222             0.180500
# 34  2005            78.111111            357.611111             0.156500
# 35  2006            73.222222            319.555556             0.164167
# 36  2007            75.222222            374.777778             0.151889
# 37  2008            81.111111            379.000000             0.145333
# 38  2009            75.777778            360.277778             0.127333
# 39  2010            81.176471            408.941176             0.186353
# 40  2011            55.333333            243.222222             0.122278
# 41  2012            57.333333            245.888889             0.142833
# 42  2013            80.222222            371.833333             0.169500
# 43  2014            82.611111            379.833333             0.140944
# 44  2015            76.888889            345.777778             0.156944
# 45  2016            63.055556            259.888889             0.127333
# 46  2017            79.388889            351.722222             0.148278
# 47  2018            70.722222            368.611111             0.140889
# 48  2019            64.944444            306.111111             0.166222
# 49  2020            64.833333            270.666667             0.161111
# 50  2021            62.833333            262.722222             0.140111
# 51  2022            59.000000            270.777778             0.159389
#
#     mean_annual_daytime_peak_ppm  mean_days_over_0_06_lag1  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                 88.222222
# 5                       0.060286                127.333333
# 6                       0.048476                124.523810
# 7                       0.029952                 54.238095
# 8                       0.029095                 24.952381
# 9                       0.027905                 17.333333
# 10                      0.026762                 12.190476
# 11                      0.029524                 11.619048
# 12                      0.033762                 17.666667
# 13                      0.035429                 34.809524
# 14                      0.033667                 31.476190
# 15                      0.028476                 34.666667
# 16                      0.033563                 20.047619
# 17                      0.030062                 38.937500
# 18                      0.028438                 26.625000
# 19                      0.037529                 21.125000
# 20                      0.037111                 44.411765
# 21                      0.038789                 51.111111
# 22                      0.034789                 46.368421
# 23                      0.040000                 31.210526
# 24                      0.040737                 56.263158
# 25                      0.037789                 51.631579
# 26                      0.039105                 41.421053
# 27                      0.037000                 51.368421
# 28                      0.040056                 47.500000
# 29                      0.042000                 61.166667
# 30                      0.044722                 74.388889
# 31                      0.043389                 78.000000
# 32                      0.041611                 71.777778
# 33                      0.043611                 61.055556
# 34                      0.045667                 71.888889
# 35                      0.044278                 78.111111
# 36                      0.044389                 73.222222
# 37                      0.046111                 75.222222
# 38                      0.044556                 81.111111
# 39                      0.047471                 75.777778
# 40                      0.041000                 81.176471
# 41                      0.043333                 55.333333
# 42                      0.046389                 57.333333
# 43                      0.045722                 80.222222
# 44                      0.046000                 82.611111
# 45                      0.044222                 76.888889
# 46                      0.046722                 63.055556
# 47                      0.046111                 79.388889
# 48                      0.045611                 70.722222
# 49                      0.044944                 64.944444
# 50                      0.046444                 64.833333
# 51                      0.045500                 62.833333
#
#     mean_hours_over_0_06_lag1  mean_max_hourly_ppm_lag1  \
# 0                         NaN                       NaN
# 1                         NaN                  0.227778
# 2                         NaN                  0.251818
# 3                 1293.500000                  0.254167
# 4                  333.222222                  0.195556
# 5                  539.095238                  0.239048
# 6                  477.333333                  0.226667
# 7                  145.476190                  0.151905
# 8                   72.285714                  0.119048
# 9                   55.333333                  0.120952
# 10                  32.619048                  0.100000
# 11                  33.666667                  0.096667
# 12                  59.142857                  0.122857
# 13                 119.904762                  0.116381
# 14                 106.476190                  0.144905
# 15                 117.857143                  0.120524
# 16                  57.619048                  0.096048
# 17                 155.812500                  0.147437
# 18                  83.625000                  0.118375
# 19                  63.375000                  0.105875
# 20                 155.000000                  0.144412
# 21                 214.222222                  0.177389
# 22                 187.947368                  0.137632
# 23                 110.157895                  0.146368
# 24                 228.000000                  0.170263
# 25                 192.631579                  0.144421
# 26                 147.894737                  0.125421
# 27                 198.789474                  0.129947
# 28                 187.833333                  0.158556
# 29                 260.000000                  0.127889
# 30                 330.166667                  0.151500
# 31                 358.944444                  0.168667
# 32                 351.277778                  0.188222
# 33                 259.611111                  0.170556
# 34                 344.222222                  0.180500
# 35                 357.611111                  0.156500
# 36                 319.555556                  0.164167
# 37                 374.777778                  0.151889
# 38                 379.000000                  0.145333
# 39                 360.277778                  0.127333
# 40                 408.941176                  0.186353
# 41                 243.222222                  0.122278
# 42                 245.888889                  0.142833
# 43                 371.833333                  0.169500
# 44                 379.833333                  0.140944
# 45                 345.777778                  0.156944
# 46                 259.888889                  0.127333
# 47                 351.722222                  0.148278
# 48                 368.611111                  0.140889
# 49                 306.111111                  0.166222
# 50                 270.666667                  0.161111
# 51                 262.722222                  0.140111
#
#     mean_annual_daytime_peak_ppm_lag1
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                            0.060286
# 7                            0.048476
# 8                            0.029952
# 9                            0.029095
# 10                           0.027905
# 11                           0.026762
# 12                           0.029524
# 13                           0.033762
# 14                           0.035429
# 15                           0.033667
# 16                           0.028476
# 17                           0.033563
# 18                           0.030062
# 19                           0.028438
# 20                           0.037529
# 21                           0.037111
# 22                           0.038789
# 23                           0.034789
# 24                           0.040000
# 25                           0.040737
# 26                           0.037789
# 27                           0.039105
# 28                           0.037000
# 29                           0.040056
# 30                           0.042000
# 31                           0.044722
# 32                           0.043389
# 33                           0.041611
# 34                           0.043611
# 35                           0.045667
# 36                           0.044278
# 37                           0.044389
# 38                           0.046111
# 39                           0.044556
# 40                           0.047471
# 41                           0.041000
# 42                           0.043333
# 43                           0.046389
# 44                           0.045722
# 45                           0.046000
# 46                           0.044222
# 47                           0.046722
# 48                           0.046111
# 49                           0.045611
# 50                           0.044944
# 51                           0.046444

# %%
# =============================================================================
# TEMPERATURE DATA
# =============================================================================
import openpyxl

weather_file_path = BASE_DIR / "Weather" / "Weather_tokyo.xlsx"
df_yearly_temps = (
    pd.read_excel(weather_file_path, skiprows=6)
      .iloc[:, [0, 7, 8, 9, 10, 11]]
)

df_yearly_temps.columns = [
    "year", "daily_mean", "daily_max", "daily_min",
    "max_temp", "min_temp"
]

# clean numeric values
def clean_num(x):
    if pd.isna(x): return np.nan
    return float(str(x).replace("]", ""))

for col in ["daily_mean", "daily_max", "daily_min", "max_temp", "min_temp"]:
    df_yearly_temps[col] = df_yearly_temps[col].map(clean_num).round(1)

df_yearly_temps = df_yearly_temps[
    (df_yearly_temps["year"].notna()) & (df_yearly_temps["year"] <= 2024)
]

# add lag1 variables
df_yearly_temps_lagged = df_yearly_temps.copy()
for col in ["daily_mean", "daily_max", "daily_min", "max_temp", "min_temp"]:
    df_yearly_temps_lagged[col + "_lag1"] = df_yearly_temps_lagged[col].shift(1)

print(df_yearly_temps_lagged.head())
# Out:
#    year  daily_mean  daily_max  daily_min  max_temp  min_temp  \
# 0  1876        13.6       18.7        8.3      35.6      -9.2
# 1  1877        14.2       19.1        8.9      34.9      -4.8
# 2  1878        13.8       18.3        9.6      35.1      -7.6
# 3  1879        14.6       19.4       10.0      33.9      -5.5
# 4  1880        14.1       19.2        9.1      33.2      -6.8
#
#    daily_mean_lag1  daily_max_lag1  daily_min_lag1  max_temp_lag1  \
# 0              NaN             NaN             NaN            NaN
# 1             13.6            18.7             8.3           35.6
# 2             14.2            19.1             8.9           34.9
# 3             13.8            18.3             9.6           35.1
# 4             14.6            19.4            10.0           33.9
#
#    min_temp_lag1
# 0            NaN
# 1           -9.2
# 2           -4.8
# 3           -7.6
# 4           -5.5

# %%
# =============================================================================
# MORTALITY & POPULATION DATA
# =============================================================================

def read_ipss_table(path):
    """Auto-detect starting line, like R version."""
    # read raw lines
    with open(path, "r") as f:
        lines = f.readlines()

    hdr_line = None
    data_line = None

    for i, ln in enumerate(lines):
        if re.match(r"^\s*Year\s+Age\s+Female\s+Male\s+Total\s*$", ln):
            hdr_line = i
            break

    for i, ln in enumerate(lines):
        if re.match(r"^\s*\d{4}\s+\S+\s+[-0-9.]+\s+[-0-9.]+\s+[-0-9.]+\s*$", ln):
            data_line = i
            break

    start = hdr_line if hdr_line is not None else data_line
    if start is None:
        raise ValueError(f"Could not detect table start in: {path}")

    # pandas read from detected line
    if hdr_line is not None:
        df = pd.read_table(path, skiprows=hdr_line, sep=r"\s+")
    else:
        df = pd.read_table(path, skiprows=data_line, sep=r"\s+",
                           names=["Year", "Age", "Female", "Male", "Total"])

    # clean Age
    df["Age"] = df["Age"].astype(str).str.strip()
    df["Age"] = df["Age"].str.replace(r"\s+", "", regex=True)
    return df


def collapse_age(age):
    age = age.replace(" ", "")
    if age == "0": return "0"
    if age == "1-4": return "1-4"
    if age in ["5-9", "10-14"]: return "5-14"
    if age in ["15-19", "20-24"]: return "15-24"
    if age in ["25-29","30-34","35-39","40-44"]: return "25-44"
    if age in ["45-49","50-54","55-59","60-64"]: return "45-64"
    if age in ["65-69","70-74"]: return "65-74"
    if age in ["75-79","80-84"]: return "75-84"
    if age in ["85-89","90-94"]: return "85-94"
    if age in ["95-99","100-104","105-109","110+"]: return "95+"
    return None


def aggregate_by_year_sex(path, year_min=1947, year_max=2023):
    df = read_ipss_table(path)
    df = df[(df["Year"] >= year_min) & (df["Year"] <= year_max)]

    df["age_group"] = df["Age"].apply(collapse_age)
    df = df[df["age_group"].notna()]

    female = df.groupby(["Year", "age_group"])["Female"].sum().reset_index()
    female = female.pivot(index="Year", columns="age_group", values="Female").reset_index()

    male   = df.groupby(["Year", "age_group"])["Male"].sum().reset_index()
    male   = male.pivot(index="Year", columns="age_group", values="Male").reset_index()

    return {"female": female, "male": male}


# load deaths + population
deaths_file_path = BASE_DIR / "Mortality" / "IPSS" / "Deaths_5x1.txt"
population_file_path = BASE_DIR / "Mortality" / "IPSS" / "Population5.txt"

deaths_ts = aggregate_by_year_sex(deaths_file_path)
pop_ts    = aggregate_by_year_sex(population_file_path)


# --- combine into long form ---
age_levels = ["0","1-4","5-14","15-24","25-44","45-64","65-74","75-84","85-94","95+"]
sex_levels = ["Female", "Male"]

def make_long(df, sex, metric):
    df_long = df.melt(id_vars="Year", var_name="age_group", value_name=metric)
    df_long["sex"] = sex
    df_long = df_long.rename(columns={"Year": "year"})
    return df_long

def combine_four(deaths_ts, pop_ts):
    d_f = make_long(deaths_ts["female"], "Female", "Deaths")
    d_m = make_long(deaths_ts["male"],   "Male",   "Deaths")

    p_f = make_long(pop_ts["female"], "Female", "Population")
    p_m = make_long(pop_ts["male"],   "Male",   "Population")

    df_f = d_f.merge(p_f, on=["year","age_group","sex"])
    df_m = d_m.merge(p_m, on=["year","age_group","sex"])

    df = pd.concat([df_f, df_m])
    df["age_group"] = pd.Categorical(df["age_group"], categories=age_levels, ordered=True)
    df["sex"] = pd.Categorical(df["sex"], categories=sex_levels, ordered=True)
    return df.sort_values(["year","sex","age_group"])


df_long_ts = combine_four(deaths_ts, pop_ts)

# %%
# =============================================================================
# VEHICLE DATA
# =============================================================================
veh_dir = BASE_DIR / "Vehicles"

# -----------------------------
# Find all Excel files in the folder
# -----------------------------
from pathlib import Path

veh_dir = BASE_DIR / "Vehicles"

# Recursive, include all Excel formats, ignore temporary files
excel_files = [f for f in veh_dir.rglob("*.xls*") if not f.name.startswith("~$")]

print(f"Found {len(excel_files)} Excel files.")
for f in excel_files:
    print(f)
# Out:
# Found 52 Excel files.
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005hm.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005ii.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005je.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/r5c6pv000000v5aq.xlsx
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005ei.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005dm.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005fe.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005ga.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005iy.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005f6.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005g2.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005fu.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005gq.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005ey.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/r5c6pv0000013d12.xlsx
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005j6.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/r5c6pv0000005s23.xlsx
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/r5c6pv000000mdpm.xlsx
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005bm.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005ci.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005aa.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005aq.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005cy.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005a2.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005be.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005ca.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005ai.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/r5c6pv000000ktsj.xlsx
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005ay.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005bu.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005cq.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph000000059u.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005c2.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/r5c6pv000000e1ws.xlsx
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005he.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005ia.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005ea.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005de.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005fm.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005gi.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/r5c6pv0000003mvc.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005e2.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005d6.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005hu.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005iq.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/r5c6pv000000z01w.xlsx
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005h6.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005i2.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005gy.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005eq.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/e49tph00000005du.xls
# /Users/apple/Desktop/2025_research_paper_lam/OxTemp_Annual_2/Vehicles/r5c6pv000000u5pc.xlsx

# %%
# Function to convert Japanese era year to Western year
def convert_japanese_year(cell):
    if not isinstance(cell, str):
        cell = str(cell)
    # Western year YYYY年
    m = re.search(r"(\d{4})年", cell)
    if m:
        return int(m.group(1))
    # Japanese era
    m = re.search(r"(昭和|平成|令和)(\d+)", cell)
    if m:
        era, y = m.groups()
        y = int(y)
        if era == "昭和":
            return 1926 + y - 1
        elif era == "平成":
            return 1989 + y - 1
        elif era == "令和":
            return 2019 + y - 1
    return None

# %%
# -----------------------------
# Loop over files and extract info
# -----------------------------
records = []

for f in excel_files:
    try:
        # Skip temp files
        if f.name.startswith("~$"):
            continue

        # Read Excel with correct engine
        if f.suffix.lower() == ".xls":
            df_excel = pd.read_excel(f, sheet_name=0, header=None, engine="xlrd")
        else:
            df_excel = pd.read_excel(f, sheet_name=0, header=None, engine="openpyxl")
        df_str = df_excel.astype(str)

        # Find Tokyo row
        tokyo_row_idx = None
        for r in range(df_str.shape[0]):
            if "東京" in df_str.iloc[r, :].values:
                tokyo_row_idx = r
                break

        # Extract all vehicle counts in that row
        vehicle_count = None
        place = "Tokyo"
        
        if tokyo_row_idx is not None:  
            for c in range(df_str.shape[1]):
                cell = df_str.iloc[tokyo_row_idx, c]
                num_cell_clean = re.sub(r"[^\d]", "", str(cell))
                if num_cell_clean.isdigit():
                    vehicle_count = int(num_cell_clean)
                    # Heuristic: passenger cars are often in the range of thousands to millions     
         # Extract year: first cell with 年 or Japanese era
        year = None
        for r in range(df_str.shape[0]):
            for c in range(df_str.shape[1]):
                year = convert_japanese_year(df_str.iloc[r, c])
                if year is not None:
                    break
            if year is not None:
                break

        # Add record
        records.append({
            "filename": f.name,
            "filepath": str(f),
            "year": year,
            "place": place,
            "vehicles": vehicle_count
        })

    except Exception as e:
        print(f"Error reading {f.name}: {e}")

# Combine into DataFrame
df_vehicle_count = pd.DataFrame(records).sort_values("year").reset_index(drop=True)
print(df_vehicle_count.head(60))
# Out:
#                  filename                                           filepath  \
# 0    e49tph000000059u.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 1    e49tph00000005a2.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 2    e49tph00000005aa.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 3    e49tph00000005ai.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 4    e49tph00000005aq.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 5    e49tph00000005ay.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 6    e49tph00000005be.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 7    e49tph00000005bm.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 8    e49tph00000005bu.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 9    e49tph00000005c2.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 10   e49tph00000005ca.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 11   e49tph00000005ci.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 12   e49tph00000005cq.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 13   e49tph00000005cy.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 14   e49tph00000005d6.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 15   e49tph00000005de.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 16   e49tph00000005dm.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 17   e49tph00000005du.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 18   e49tph00000005e2.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 19   e49tph00000005ea.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 20   e49tph00000005ei.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 21   e49tph00000005eq.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 22   e49tph00000005ey.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 23   e49tph00000005f6.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 24   e49tph00000005fe.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 25   e49tph00000005fm.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 26   e49tph00000005fu.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 27   e49tph00000005g2.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 28   e49tph00000005ga.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 29   e49tph00000005gi.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 30   e49tph00000005gq.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 31   e49tph00000005gy.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 32   e49tph00000005h6.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 33   e49tph00000005he.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 34   e49tph00000005hm.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 35   e49tph00000005hu.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 36   e49tph00000005i2.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 37   e49tph00000005ia.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 38   e49tph00000005ii.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 39   e49tph00000005iq.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 40   e49tph00000005iy.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 41   e49tph00000005j6.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 42   e49tph00000005je.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 43   r5c6pv0000003mvc.xls  /Users/apple/Desktop/2025_research_paper_lam/O...
# 44  r5c6pv0000005s23.xlsx  /Users/apple/Desktop/2025_research_paper_lam/O...
# 45  r5c6pv000000e1ws.xlsx  /Users/apple/Desktop/2025_research_paper_lam/O...
# 46  r5c6pv000000ktsj.xlsx  /Users/apple/Desktop/2025_research_paper_lam/O...
# 47  r5c6pv000000mdpm.xlsx  /Users/apple/Desktop/2025_research_paper_lam/O...
# 48  r5c6pv000000u5pc.xlsx  /Users/apple/Desktop/2025_research_paper_lam/O...
# 49  r5c6pv000000v5aq.xlsx  /Users/apple/Desktop/2025_research_paper_lam/O...
# 50  r5c6pv000000z01w.xlsx  /Users/apple/Desktop/2025_research_paper_lam/O...
# 51  r5c6pv0000013d12.xlsx  /Users/apple/Desktop/2025_research_paper_lam/O...
#
#     year  place  vehicles
# 0   1971  Tokyo   2213211
# 1   1972  Tokyo   2359757
# 2   1973  Tokyo   2510580
# 3   1974  Tokyo   2601320
# 4   1975  Tokyo   2646659
# 5   1976  Tokyo   2654649
# 6   1978  Tokyo   2828315
# 7   1979  Tokyo   2954941
# 8   1980  Tokyo   3088725
# 9   1981  Tokyo   3090858
# 10  1982  Tokyo   3213801
# 11  1983  Tokyo   3334514
# 12  1984  Tokyo   3470403
# 13  1985  Tokyo   3600988
# 14  1986  Tokyo   3737625
# 15  1987  Tokyo   3872139
# 16  1988  Tokyo   4058313
# 17  1989  Tokyo   4228468
# 18  1990  Tokyo   4429318
# 19  1991  Tokyo   4529125
# 20  1992  Tokyo   4566772
# 21  1993  Tokyo   4564307
# 22  1994  Tokyo   4571625
# 23  1995  Tokyo   4584003
# 24  1996  Tokyo   4616729
# 25  1997  Tokyo   4651077
# 26  1998  Tokyo   4645002
# 27  1999  Tokyo   4624068
# 28  2000  Tokyo   4618040
# 29  2001  Tokyo   4623017
# 30  2002  Tokyo   4624131
# 31  2003  Tokyo   4622339
# 32  2004  Tokyo   4608377
# 33  2005  Tokyo   4627674
# 34  2006  Tokyo   4638303
# 35  2007  Tokyo   4617449
# 36  2008  Tokyo   4591468
# 37  2009  Tokyo   4518967
# 38  2010  Tokyo   4472022
# 39  2011  Tokyo   4430557
# 40  2012  Tokyo   4417097
# 41  2013  Tokyo   4408801
# 42  2014  Tokyo   4415951
# 43  2015  Tokyo   4413094
# 44  2016  Tokyo   4413157
# 45  2017  Tokyo   4419010
# 46  2018  Tokyo   4419478
# 47  2019  Tokyo   4414981
# 48  2020  Tokyo   4409797
# 49  2021  Tokyo   4408196
# 50  2022  Tokyo   4416116
# 51  2023  Tokyo   4424593

# %%
# =============================================================================
# MERGE Mortality + Temperature + Ozone + Vehicles (Tokyo)
# =============================================================================

df_mort_ozone_temp_veh = (
    df_long_ts
    .merge(df_yearly_temps_lagged, on="year", how="left")
    .merge(df_results_ozone_lagged, on="year", how="left")
    .merge(df_vehicle_count, on="year", how="left")
)

# Filter years 1978–2022
df_mort_ozone_temp_veh = df_mort_ozone_temp_veh[
    (df_mort_ozone_temp_veh["year"] >= 1978) &
    (df_mort_ozone_temp_veh["year"] <= 2022)
]

# Check
print(df_mort_ozone_temp_veh.head())

# Save to a specific directory
output_path = BASE_DIR / "Processed" / "df_mort_ozone_temp_veh.pkl"
df_mort_ozone_temp_veh.to_pickle(output_path)
# Out:
#      year age_group   Deaths     sex  Population  daily_mean  daily_max  \
# 620  1978         0   512.69  Female    77688.82        16.1       20.0
# 621  1978       1-4   170.16  Female   342693.45        16.1       20.0
# 622  1978      5-14   157.11  Female   814168.25        16.1       20.0
# 623  1978     15-24   259.40  Female   898877.05        16.1       20.0
# 624  1978     25-44  1602.38  Female  1999960.53        16.1       20.0
#
#      daily_min  max_temp  min_temp  ...  mean_max_hourly_ppm  \
# 620       12.6      36.3      -2.0  ...             0.119048
# 621       12.6      36.3      -2.0  ...             0.119048
# 622       12.6      36.3      -2.0  ...             0.119048
# 623       12.6      36.3      -2.0  ...             0.119048
# 624       12.6      36.3      -2.0  ...             0.119048
#
#      mean_annual_daytime_peak_ppm  mean_days_over_0_06_lag1  \
# 620                      0.029952                 54.238095
# 621                      0.029952                 54.238095
# 622                      0.029952                 54.238095
# 623                      0.029952                 54.238095
# 624                      0.029952                 54.238095
#
#      mean_hours_over_0_06_lag1  mean_max_hourly_ppm_lag1  \
# 620                  145.47619                  0.151905
# 621                  145.47619                  0.151905
# 622                  145.47619                  0.151905
# 623                  145.47619                  0.151905
# 624                  145.47619                  0.151905
#
#      mean_annual_daytime_peak_ppm_lag1              filename  \
# 620                           0.048476  e49tph00000005be.xls
# 621                           0.048476  e49tph00000005be.xls
# 622                           0.048476  e49tph00000005be.xls
# 623                           0.048476  e49tph00000005be.xls
# 624                           0.048476  e49tph00000005be.xls
#
#                                               filepath  place   vehicles
# 620  /Users/apple/Desktop/2025_research_paper_lam/O...  Tokyo  2828315.0
# 621  /Users/apple/Desktop/2025_research_paper_lam/O...  Tokyo  2828315.0
# 622  /Users/apple/Desktop/2025_research_paper_lam/O...  Tokyo  2828315.0
# 623  /Users/apple/Desktop/2025_research_paper_lam/O...  Tokyo  2828315.0
# 624  /Users/apple/Desktop/2025_research_paper_lam/O...  Tokyo  2828315.0
#
# [5 rows x 27 columns]
